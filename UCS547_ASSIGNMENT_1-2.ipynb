# %% [markdown]
# **Name:Tushar**
#
#
#
#
# **ROLL NO:102303206**
#
#
#
#
#
#
# **Assignment1(UCS547)**

# %%
import numpy as np

# %% [markdown]
#  Ques.1  Reverse the NumPy array: arr = np.array([1, 2, 3, 6, 4, 5]) )

# %%
arr = np.array([15,18,20,56,67])
reversed_arr = arr[::-1]

print("Original array:", arr)
print("Reversed array:", reversed_arr)
# Out:
# Original array: [15 18 20 56 67]
# Reversed array: [67 56 20 18 15]

# %% [markdown]
# Ques. 2. Compare the following numpy arrays: arr1 = np.array([[1, 2], [3, 4]])
#
# arr2 = np.array([[1, 2], [3, 4]])

# %%
arr1 = np.array([[1, 2], [3, 4]])
arr2 = np.array([[1, 3], [3, 4]])

comparison = arr1 == arr2
are_equal = np.array_equal(arr1, arr2)

print("Element-wise comparison:\n", comparison)
print("Are both arrays completely equal?", are_equal)
# Out:
# Element-wise comparison:
#  [[ True False]
#  [ True  True]]
# Are both arrays completely equal? False

# %% [markdown]
# Ques.3 Find the most frequent value and their indice(s) in the following arrays:
#
# i. x = np.array([1,2,3,4,5,1,2,1,1,1])
#
# ii. y = np.array([1, 1, 1, 2, 3, 4, 2, 4, 3, 3, ])

# %%
# Q3(i): Most frequent value and indices in x
x = np.array([1,2,3,4,5,1,2,1,1,1,4,4,4,4,4,4,4])

values, counts = np.unique(x, return_counts=True)
most_frequent_value = values[np.argmax(counts)]
indices = np.where(x == most_frequent_value)

print("Array x:", x)
print("Most frequent value:", most_frequent_value)
print("Indices:", indices)
# Out:
# Array x: [1 2 3 4 5 1 2 1 1 1 4 4 4 4 4 4 4]
# Most frequent value: 4
# Indices: (array([ 3, 10, 11, 12, 13, 14, 15, 16]),)

# %%
# Q3(ii): Most frequent value and indices in y
y = np.array([1,2, 3, 4, 2, 4, 3, 3])

values, counts = np.unique(y, return_counts=True)
most_frequent_value = values[np.argmax(counts)]
indices = np.where(y == most_frequent_value)

print("Array y:", y)
print("Most frequent value:", most_frequent_value)
print("Indices:", indices)
# Out:
# Array y: [1 2 3 4 2 4 3 3]
# Most frequent value: 3
# Indices: (array([2, 6, 7]),)

# %% [markdown]
# Ques.4. For the array gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]'),
# find
#
# i. Sum of all elements
#
# ii. Sum of all element’s row-wise
#
# iii. Sum of all element’s column-wise

# %%
gfg = np.matrix('[8, 5, 14; 12, 73, 1; 4, 75, 16]')

# i. Sum of all elements
total_sum = gfg.sum()

# ii. Row-wise sum
row_wise_sum = gfg.sum(axis=1)

# iii. Column-wise sum
column_wise_sum = gfg.sum(axis=0)

print("Matrix:\n", gfg)
print("Sum of all elements:", total_sum)
print("Row-wise sum:\n", row_wise_sum)
print("Column-wise sum:\n", column_wise_sum)
# Out:
# Matrix:
#  [[ 8  5 14]
#  [12 73  1]
#  [ 4 75 16]]
# Sum of all elements: 208
# Row-wise sum:
#  [[27]
#  [86]
#  [95]]
# Column-wise sum:
#  [[ 24 153  31]]
